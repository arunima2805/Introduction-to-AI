# %% [markdown]
# <a href="https://colab.research.google.com/github/arunima2805/Introduction-to-AI/blob/main/CheckingRoutesBetweenCitiesUsingDFS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Problem 3
# Road network represented using an adjacency list
graph = {
    'A': ['B', 'C'],
    'B': ['A', 'D'],
    'C': ['A', 'D'],
    'D': ['B', 'C', 'E'],
    'E': ['D'],
    'F': ['G'],
    'G': ['F']
}


# 1. Check whether a route exists between two cities
def route_exists(graph, start, destination, visited=None):
    if visited is None:
        visited = set()

    # If we reached the destination
    if start == destination:
        return True

    visited.add(start)

    # Visit all connected cities
    for city in graph[start]:
        if city not in visited:
            if route_exists(graph, city, destination, visited):
                return True

    return False


# 2. Find all connected components
def find_components(graph):
    visited = set()
    components = []

    for city in graph:
        if city not in visited:
            component = []

            def dfs(node):
                visited.add(node)
                component.append(node)

                for neighbour in graph[node]:
                    if neighbour not in visited:
                        dfs(neighbour)

            dfs(city)
            components.append(component)

    return components


# Check routes
start_city = 'A'
destination_city = 'E'

if route_exists(graph, start_city, destination_city):
    print(f"Route exists from {start_city} to {destination_city}")
else:
    print(f"No route exists from {start_city} to {destination_city}")


# Check another route
start_city = 'A'
destination_city = 'F'

if route_exists(graph, start_city, destination_city):
    print(f"Route exists from {start_city} to {destination_city}")
else:
    print(f"No route exists from {start_city} to {destination_city}")


# Find connected components
components = find_components(graph)

print("\nConnected Components:")

for i, component in enumerate(components, 1):
    print(f"Component {i}: {component}")
# Out:
# Route exists from A to E
# No route exists from A to F
#
# Connected Components:
# Component 1: ['A', 'B', 'D', 'C', 'E']
# Component 2: ['F', 'G']
